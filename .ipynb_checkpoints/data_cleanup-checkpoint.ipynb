# %%
# import dependencies
import os
import spotipy
import spotipy.util as util
import pandas as pd
import csv
from pprint import pprint

Client_ID = "7655188a18144343b07e44965cc38310"

Client_Secret = "2bec9b47853e4ea3a419418a211ec45d"

# %%
top_2017 = pd.read_csv("resources/featuresdf.csv")
top_2018 = pd.read_csv("resources/top2018.csv")
top_2019 = pd.read_csv("resources/top50.csv", encoding='cp1252')

# %%
top_2019.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
#top_2017.head()
#https://open.spotify.com/user/1298997744?si=ijwp9NZOQoyjO9qOZliclw
SPOTIPY_CLIENT_ID='7655188a18144343b07e44965cc38310'
SPOTIPY_CLIENT_SECRET='2bec9b47853e4ea3a419418a211ec45d'
SPOTIPY_REDIRECT_URI='https://google.com/'
scope = 'user-library-read'
# Grab username
username = "1298997744"

token = util.prompt_for_user_token(username, scope, client_id=SPOTIPY_CLIENT_ID,client_secret=SPOTIPY_CLIENT_SECRET,redirect_uri=SPOTIPY_REDIRECT_URI)

# Create our spotify object

# if token:
#     sp = spotipy.Spotify(auth=token)
#     results = sp.current_user_saved_tracks()
#     for item in results['items']:
#         track = item['track']
#         print(track['name'] + ' - ' + track['artists'][0]['name'])
# else:
#     print("Can't get token for", username)
name = 'Shawn Mendes'
if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.search(q='artist: ' + name)
    pprint(results)
else:
    print("Can't get token for", username)

#util.prompt_for_user_token(username,scope,client_id='your-app-redirect-url',client_secret='your-app-redirect-url',redirect_uri='your-app-redirect-url')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3A+Shawn+Mendes&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                               'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                               'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                               'name': 'Shawn Mendes',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#                                               'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#                                               'id': '4nDoRrQiYLoBzwC5BhVJzF',
#                                               'name': 'Camila Cabello',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2ZaX1FdZCwchXl1QZiD4O4'},
#                                  'href': 'https://api.spotify.com/v1/albums/2ZaX1FdZCwchXl1QZiD4O4',
#                                  'id': '2ZaX1FdZCwchXl1QZiD4O4',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/848e61858fa76a1a1e262286a53c937dfba85237',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/a5390507d93a2c49d3ce3d7b7d483e4153bce965',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/b0d36f3a80a36960e34c04f21ba44e05ccf5991b',
#                                              'width': 64}],
#                                  'name': 'Señorita',
#                                  'release_date': '2019-06-21',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2ZaX1FdZCwchXl1QZiD4O4'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                     'name': 'Shawn Mendes',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#                                     'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#                                     'id': '4nDoRrQiYLoBzwC5BhVJzF',
#                                     'name': 'Camila Cabello',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 190960,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71911283'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0TK2YIli7K1leLovkQiNik'},
#                        'href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#                        'id': '0TK2YIli7K1leLovkQiNik',
#                        'is_local': False,
#                        'name': 'Señorita',
#                        'popularity': 96,
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                               'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                               'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                               'name': 'Shawn Mendes',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1J2BrRxtQjVUa7X9Ne99xD'},
#                                  'href': 'https://api.spotify.com/v1/albums/1J2BrRxtQjVUa7X9Ne99xD',
#                                  'id': '1J2BrRxtQjVUa7X9Ne99xD',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/50a23762ffe11c9f8d82450b6015f2d3685b5fe6',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/538e15fc83433e9d60029a579ba8117aed365af3',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/fc0fdce518f3abc901a2ce9b095028e021227985',
#                                              'width': 64}],
#                                  'name': "If I Can't Have You",
#                                  'release_date': '2019-05-03',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1J2BrRxtQjVUa7X9Ne99xD'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                     'name': 'Shawn Mendes',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 190800,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71907349'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6LsAAHotRLMOHfCsSfYCsz'},
#                        'href': 'https://api.spotify.com/v1/tracks/6LsAAHotRLMOHfCsSfYCsz',
#                        'id': '6LsAAHotRLMOHfCsSfYCsz',
#                        'is_local': False,
#                        'name': "If I Can't Have You",
#                        'popularity': 87,
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:6LsAAHotRLMOHfCsSfYCsz'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                               'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                               'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                               'name': 'Shawn Mendes',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0xzScN8P3hQAz3BT3YYX5w'},
#                                  'href': 'https://api.spotify.com/v1/albums/0xzScN8P3hQAz3BT3YYX5w',
#                                  'id': '0xzScN8P3hQAz3BT3YYX5w',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/93de84650354b3a8436a893332b436cf3bb000d0',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/4e75d4d2bc7fbd8d3b48c37f8c2ead1f36774e49',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/b68c52237ed6815023eb6e62ab93e380c04611a6',
#                                              'width': 64}],
#                                  'name': 'Shawn Mendes (Deluxe)',
#                                  'release_date': '2019-06-19',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0xzScN8P3hQAz3BT3YYX5w'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                     'name': 'Shawn Mendes',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#                                     'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#                                     'id': '4nDoRrQiYLoBzwC5BhVJzF',
#                                     'name': 'Camila Cabello',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 190799,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71911283'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6v3KW9xbzN5yKLt9YKDYA2'},
#                        'href': 'https://api.spotify.com/v1/tracks/6v3KW9xbzN5yKLt9YKDYA2',
#                        'id': '6v3KW9xbzN5yKLt9YKDYA2',
#                        'is_local': False,
#                        'name': 'Señorita',
#                        'popularity': 89,
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:6v3KW9xbzN5yKLt9YKDYA2'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                               'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                               'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                               'name': 'Shawn Mendes',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2VP96XdMOKTXefI8Nui23s'},
#                                  'href': 'https://api.spotify.com/v1/albums/2VP96XdMOKTXefI8Nui23s',
#                                  'id': '2VP96XdMOKTXefI8Nui23s',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/93de84650354b3a8436a893332b436cf3bb000d0',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/4e75d4d2bc7fbd8d3b48c37f8c2ead1f36774e49',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/b68c52237ed6815023eb6e62ab93e380c04611a6',
#                                              'width': 64}],
#                                  'name': 'Shawn Mendes',
#                                  'release_date': '2018-05-25',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 14,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2VP96XdMOKTXefI8Nui23s'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                     'name': 'Shawn Mendes',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
# ...
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 208733,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71603531'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0AS63m1wHv9n4VVRizK6Hc'},
#                        'href': 'https://api.spotify.com/v1/tracks/0AS63m1wHv9n4VVRizK6Hc',
#                        'id': '0AS63m1wHv9n4VVRizK6Hc',
#                        'is_local': False,
#                        'name': 'Mercy',
#                        'popularity': 82,
#                        'preview_url': None,
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:0AS63m1wHv9n4VVRizK6Hc'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                               'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                               'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                               'name': 'Shawn Mendes',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6sUOosXuYt0oUeczJRbedZ'},
#                                  'href': 'https://api.spotify.com/v1/albums/6sUOosXuYt0oUeczJRbedZ',
#                                  'id': '6sUOosXuYt0oUeczJRbedZ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/bb2f0a7e53686ad9b98a438f896e42c190f39560',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/9643783b15fdb7c362a8af983636e1a66be507d0',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/14bc6485ba7cab6c3e412e663c753054649276cf',
#                                              'width': 64}],
#                                  'name': 'Handwritten',
#                                  'release_date': '2015-04-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 13,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6sUOosXuYt0oUeczJRbedZ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                     'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                     'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                     'name': 'Shawn Mendes',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 206880,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71500658'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5jsw9uXEGuKyJzs0boZ1bT'},
#                        'href': 'https://api.spotify.com/v1/tracks/5jsw9uXEGuKyJzs0boZ1bT',
#                        'id': '5jsw9uXEGuKyJzs0boZ1bT',
#                        'is_local': False,
#                        'name': 'Stitches',
#                        'popularity': 75,
#                        'preview_url': None,
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:5jsw9uXEGuKyJzs0boZ1bT'}],
#             'limit': 10,
#             'next': 'https://api.spotify.com/v1/search?query=artist%3A+Shawn+Mendes&type=track&offset=10&limit=10',
#             'offset': 0,
#             'previous': None,
#             'total': 275}}

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/search?q=artist%3AShawn+Mendes&limit=10&offset=0&type=artist
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-43-3c31734ddf08> in <module>
#       2 spotify = spotipy.Spotify()
#       3 name = "Shawn Mendes"
# ----> 4 results = spotify.search(q='artist:' + name, type='artist')
#       5 print(results)
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.6/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     122                 raise SpotifyException(r.status_code,
#     123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
# --> 124                     headers=r.headers)
#     125             else:
#     126                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 401, code:-1 - https://api.spotify.com/v1/search?q=artist%3AShawn+Mendes&limit=10&offset=0&type=artist:
#  No token provided
